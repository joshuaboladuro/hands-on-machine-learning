# %% [markdown]
# # Chapter 3 — Exercise 1: MNIST Classifier (97%+ accuracy)

# %% [markdown]
# ## Exercise
#
# Try to build a classifier for the MNIST dataset that achieves over 97% accuracy on the test set.
#
# **Hint:** The `KNeighborsClassifier` works quite well for this task; you just need to find good hyperparameter values (try a grid search on the `weights` and `n_neighbors` hyperparameters).

# %% [markdown]
# ## Approach / notes
#
# - Fetch MNIST via `sklearn.datasets.fetch_openml('mnist_784', as_frame=False)`
# - Split into train (first 60,000) and test (last 10,000)
# - Run `GridSearchCV` over `n_neighbors` in roughly `[3, 4, 5]` and `weights` in `['uniform', 'distance']`
# - Measure final accuracy on the held-out test set
#
# _Add your working notes as you go._

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ## Solution
#
# _Start writing your solution here._

# %% [markdown]
# ### Roadmap (one step per cell — fill in the code yourself)
#
# **Goal:** a multiclass classifier that predicts the digit (0–9) in a 28×28 image, reaching >97% accuracy on the test set.

# %%
# Step 1 — Get the data
#   fetch_openml('mnist_784', as_frame=False). Separate into X (pixels) and y (labels).

# %%
# Step 1 — your code here

# %%
# Step 2 — Check the data (already clean — no missing values)
#   Look at X.shape / y.shape. Reshape one row to 28x28 and display it.
#   y comes back as strings — decide if you want them as integers.

# %%
# Step 2 — your code here

# %%
# Step 3 — Split (MNIST is ALREADY split — do NOT shuffle or re-split)
#   Train = first 60,000 rows.  Test = last 10,000 rows.  (70,000 total)

# %%
# Step 3 — your code here

# %%
# Step 4 — Pick the model
#   KNeighborsClassifier.

# %%
# Step 4 — your code here

# %%
# Step 5 — Set up GridSearchCV (hyperparameter search; runs k-fold CV internally)
#   KNN's knobs to tune:
#     - n_neighbors : the K in KNN          -> candidates [3, 4, 5]
#     - weights     : 'uniform' vs 'distance' (closer neighbors count more)

# %%
# Step 5 — your code here

# %%
# Step 6 — Fit
#   Fit the grid search on the TRAINING set only.

# %%
# Step 6 — your code here

# %%
# Step 7 — Inspect results
#   Look at best_params_ and best_score_ (the best cross-validation score).

# %%
# Step 7 — your code here

# %%
# Step 8 — Final check
#   Evaluate the best model on the held-out TEST set. Do this ONCE, at the very end.

# %%
# Step 8 — your code here
